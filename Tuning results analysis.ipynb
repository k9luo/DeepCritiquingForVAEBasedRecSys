# %%
import ast
import os
import pandas as pd
pd.set_option('display.max_columns', 30)

# %%
def load_tuning_results(folder_path):
    csv_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f)) and f.endswith('.csv')]
    
    df = pd.DataFrame()
    for record in csv_files:
        df = df.append(pd.read_csv(record))
    return df

# %%
df_tuning_results = load_tuning_results(folder_path='tables/beer_rating_tuning/')
df_tuning_results = df_tuning_results.loc[df_tuning_results['lambda_keyphrase'] == df_tuning_results['lambda_latent']]
metric = 'NDCG'
df_tuning_results[metric+'_Score'] = df_tuning_results[metric].map(lambda x: ast.literal_eval(x)[0])
df_tuning_results.sort_values(by=metric+'_Score', ascending=False)
# Out:
#          model  rank    beta  lambda_l2  lambda_keyphrase  lambda_latent  \
# 89   E-CDE-VAE   100  0.0010     0.0001            0.0100         0.0100
# 261  E-CDE-VAE   100  0.0010     0.0001            0.0100         0.0100
# 306  E-CDE-VAE   200  0.0010     0.0010            0.0100         0.0100
# 336  E-CDE-VAE   200  0.0010     0.0010            0.0100         0.0100
# 318  E-CDE-VAE   200  0.0010     0.0010            0.0010         0.0010
# 144  E-CDE-VAE   100  0.0010     0.0010            0.0100         0.0100
# 300  E-CDE-VAE   200  0.0010     0.0010            0.0001         0.0001
# 261  E-CDE-VAE   100  0.0010     0.0001            0.0100         0.0100
# 303  E-CDE-VAE   200  0.0010     0.0010            0.0010         0.0010
# 309  E-CDE-VAE   200  0.0010     0.0010            0.1000         0.1000
# 300  E-CDE-VAE   200  0.0010     0.0010            0.0001         0.0001
# 300  E-CDE-VAE   200  0.0010     0.0010            0.0001         0.0001
# ...

# %%
df_tuning_results = load_tuning_results(folder_path='tables/CDsVinyl_rating_tuning/')
#df_tuning_results = df_tuning_results.loc[df_tuning_results['lambda_keyphrase'] == df_tuning_results['lambda_latent']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-19242a991748> in <module>
# ----> 1 df_tuning_results = load_tuning_results(folder_path='tables/CDsVinyl_rating_tuning/')
#       2 #df_tuning_results = df_tuning_results.loc[df_tuning_results['lambda_keyphrase'] == df_tuning_results['lambda_latent']]
#
# NameError: name 'load_tuning_results' is not defined

# %%
metric = 'NDCG'

# %%
df_tuning_results[metric+'_Score'] = df_tuning_results[metric].map(lambda x: ast.literal_eval(x)[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d7910ab3300d> in <module>
# ----> 1 df_tuning_results[metric+'_Score'] = df_tuning_results[metric].map(lambda x: ast.literal_eval(x)[0])
#
# NameError: name 'df_tuning_results' is not defined

# %%
df_tuning_results[df_tuning_results['model']=='S-E-CDE-VAE'].sort_values(by=metric+'_Score', ascending=False)
# Out:
#               MAP@10            MAP@15            MAP@20             MAP@5  \
# 0   [0.0625, 0.0029]  [0.0558, 0.0024]   [0.051, 0.0021]   [0.0724, 0.004]
# 4   [0.0622, 0.0029]  [0.0556, 0.0024]  [0.0508, 0.0021]   [0.0721, 0.004]
# 0   [0.0615, 0.0029]  [0.0551, 0.0024]  [0.0505, 0.0021]  [0.0712, 0.0039]
# 2   [0.0625, 0.0029]  [0.0559, 0.0024]  [0.0512, 0.0021]  [0.0722, 0.0039]
# 2   [0.0624, 0.0029]  [0.0558, 0.0024]   [0.051, 0.0021]  [0.0725, 0.0039]
# ..               ...               ...               ...               ...
# 4   [0.0072, 0.0009]  [0.0073, 0.0008]  [0.0071, 0.0007]  [0.0069, 0.0012]
# 1   [0.0072, 0.0009]  [0.0072, 0.0008]  [0.0071, 0.0007]   [0.007, 0.0012]
# 4   [0.0072, 0.0009]  [0.0073, 0.0008]  [0.0071, 0.0007]  [0.0069, 0.0012]
# 5   [0.0072, 0.0009]  [0.0073, 0.0008]  [0.0071, 0.0007]  [0.0069, 0.0011]
# 5   [0.0072, 0.0009]  [0.0073, 0.0008]  [0.0071, 0.0007]  [0.0069, 0.0011]
#
# ...

# %%
df_tuning_results = load_tuning_results(folder_path='tables/beer_explanation_tuning/')
df_tuning_results = df_tuning_results.loc[df_tuning_results['lambda_keyphrase'] == df_tuning_results['lambda_latent']]
metric = 'NDCG'
df_tuning_results[metric+'_Score'] = df_tuning_results[metric].map(lambda x: ast.literal_eval(x)[0])
df_tuning_results.sort_values(by=metric+'_Score', ascending=False)
# Out:
#           model  rank    beta  lambda_l2  lambda_keyphrase  lambda_latent  \
# 1048  E-CDE-VAE   100  1.0000     0.0010            1.0000         1.0000
# 201   E-CDE-VAE   200  1.0000     0.0001            0.0001         0.0001
# 150   E-CDE-VAE   200  0.0010     0.0100            0.0001         0.0001
# 286   E-CDE-VAE   100  1.0000     0.0010            0.0010         0.0010
# 370   E-CDE-VAE   100  1.0000     0.0001            0.1000         0.1000
# 369   E-CDE-VAE   100  1.0000     0.0001            0.1000         0.1000
# 287   E-CDE-VAE   100  1.0000     0.0010            0.0010         0.0010
# 366   E-CDE-VAE   100  1.0000     0.0001            0.0100         0.0100
# 283   E-CDE-VAE   100  1.0000     0.0010            0.0001         0.0001
# 363   E-CDE-VAE   100  1.0000     0.0001            0.0010         0.0010
# 361   E-CDE-VAE   100  1.0000     0.0001            0.0001         0.0001
# 361   E-CDE-VAE   200  0.0100     0.0100            0.0001         0.0001
# ...

# %%
df_tuning_results = load_tuning_results(folder_path='tables/CDsVinyl_explanation_tuning/')
#df_tuning_results = df_tuning_results.loc[df_tuning_results['lambda_keyphrase'] == df_tuning_results['lambda_latent']]
metric = 'NDCG'
df_tuning_results[metric+'_Score'] = df_tuning_results[metric].map(lambda x: ast.literal_eval(x)[0])
df_tuning_results.sort_values(by=metric+'_Score', ascending=False)
# Out:
# /home/hojin/anaconda3/envs/de/lib/python3.6/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#                MAP@10            MAP@15            MAP@20             MAP@5  \
# 588  [0.4997, 0.0067]  [0.4447, 0.0062]  [0.4035, 0.0059]   [0.583, 0.0077]
# 516   [0.499, 0.0067]  [0.4441, 0.0062]  [0.4029, 0.0058]  [0.5821, 0.0076]
# 270  [0.4984, 0.0067]  [0.4436, 0.0062]  [0.4025, 0.0058]  [0.5817, 0.0077]
# 45   [0.4981, 0.0067]  [0.4433, 0.0062]  [0.4023, 0.0058]  [0.5812, 0.0076]
# 288  [0.4969, 0.0066]  [0.4423, 0.0061]  [0.4014, 0.0058]  [0.5796, 0.0076]
# ..                ...               ...               ...               ...
# 11   [0.1064, 0.0038]  [0.1031, 0.0034]  [0.1024, 0.0032]  [0.1102, 0.0047]
# ...

# %%
df_tuning_results[df_tuning_results['model']=='S-E-CDE-VAE'].sort_values(by=metric+'_Score', ascending=False)
# Out:
#              MAP@10            MAP@15            MAP@20             MAP@5  \
# 0  [0.4744, 0.0068]  [0.4242, 0.0062]  [0.3865, 0.0058]   [0.549, 0.0078]
# 0  [0.4738, 0.0068]  [0.4237, 0.0062]   [0.386, 0.0058]  [0.5482, 0.0078]
# 0  [0.4738, 0.0068]  [0.4238, 0.0062]  [0.3863, 0.0059]  [0.5477, 0.0078]
# 0  [0.4731, 0.0068]  [0.4236, 0.0062]  [0.3861, 0.0058]  [0.5467, 0.0078]
# 0  [0.4728, 0.0067]  [0.4231, 0.0062]  [0.3856, 0.0058]  [0.5477, 0.0078]
# 0  [0.4733, 0.0068]  [0.4235, 0.0062]   [0.386, 0.0058]  [0.5479, 0.0078]
# 0  [0.4727, 0.0067]  [0.4229, 0.0062]  [0.3854, 0.0058]   [0.547, 0.0078]
# 0  [0.4729, 0.0068]  [0.4232, 0.0062]  [0.3859, 0.0058]  [0.5477, 0.0078]
# 0  [0.4732, 0.0068]  [0.4235, 0.0062]   [0.386, 0.0058]  [0.5474, 0.0078]
# 0  [0.4736, 0.0068]  [0.4236, 0.0062]  [0.3861, 0.0059]  [0.5484, 0.0078]
# 0  [0.4728, 0.0067]  [0.4228, 0.0062]  [0.3853, 0.0058]  [0.5465, 0.0078]
# 0  [0.4729, 0.0068]  [0.4232, 0.0062]  [0.3859, 0.0059]  [0.5472, 0.0078]
# ...
